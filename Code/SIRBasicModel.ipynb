# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/SMaRT2023/blob/main/Code/SIRBasicModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import solve_ivp
from scipy.integrate import odeint

# %%
def SIR(y,t, alpha, beta):
  S,I,R = y
  dydt = [-alpha*S*I,alpha*S*I - beta*I,beta*I]
  return dydt

# %%
alpha = 2
beta = 1

# %%
y0 = [.999,.001,0]

# %%
t = np.linspace(0, 10, 101)

# %%
sol = odeint(SIR, y0, t, args=(alpha, beta))

# %%
plt.plot(t, sol[:, 0], 'b', label='S')

plt.plot(t, sol[:, 1], 'g', label='I')

plt.plot(t, sol[:, 2], 'r', label='R')

plt.legend(loc='best')

plt.xlabel('t')

plt.grid()

plt.show()

# %%
F = lambda t, s: np.cos(t)

t_eval = np.arange(0, np.pi, 0.1)
sol = solve_ivp(F, [0, np.pi], [0], t_eval=t_eval)

plt.figure(figsize = (12, 4))
plt.subplot(121)
plt.plot(sol.t, sol.y[0])
plt.xlabel('t')
plt.ylabel('S(t)')
plt.subplot(122)
plt.plot(sol.t, sol.y[0] - np.sin(sol.t))
plt.xlabel('t')
plt.ylabel('S(t) - sin(t)')
plt.tight_layout()
plt.show()
